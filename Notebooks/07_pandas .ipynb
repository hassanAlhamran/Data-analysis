# %%
import pandas as pd
df=pd.read_csv('salary.csv')

# %%
df
# Out:
#     salary  gender departm  years   age  publications
# 0    86285       0     bio   26.0  64.0            72
# 1    77125       0     bio   28.0  58.0            43
# 2    71922       0     bio   10.0  38.0            23
# 3    70499       0     bio   16.0  46.0            64
# 4    66624       0     bio   11.0  41.0            23
# ..     ...     ...     ...    ...   ...           ...
# 72   53662       1   neuro    1.0  31.0             3
# 73   57185       1    stat    9.0  39.0             7
# 74   52254       1    stat    2.0  32.0             9
# 75   61885       1    math   23.0  60.0             9
# 76   49542       1    math    3.0  33.0             5
#
# [77 rows x 6 columns]

# %%
# !pip install matplot
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/630.7 kB ? eta -:--:--
#    ---------------------------------------- 630.7/630.7 kB 4.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/604.5 kB ? eta -:--:--
#    ---------------------------------------- 604.5/604.5 kB 5.8 MB/s eta 0:00:00
# ...
#   Created wheel for SimpleWebSocketServer: filename=simplewebsocketserver-0.1.2-py3-none-any.whl size=9741 sha256=9d4de4e599f06f0c869329c4592b5a1d9011b32b1e7cae7b7622a514717330e9
#   Stored in directory: c:\users\windows 10 pro\appdata\local\pip\cache\wheels\c4\5b\e8\4f2c15a82edc4923058056f6681373168be02a0c00389a6dcf
# ...

# %%
df['salary'].plot()
# Out:
# <Axes: >

# %%
df['salary'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['gender'].plot(kind='pie')
# Out:
# <Axes: ylabel='gender'>

# %%
df['gender']
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 72    1
# 73    1
# 74    1
# 75    1
# 76    1
# Name: gender, Length: 77, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# 0    67
# 1     9
# 2     1
# Name: count, dtype: int64

# %%
df['gender'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df['gender'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='gender'>

# %%
df['gender'].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['age'].plot(kind='hist');

# %%
df.groupby( ['departm','gender' ])['age'].count()
# Out:
# departm  gender
# bio      0         14
#          1          2
# chem     0          9
#          1          1
# geol     0          4
# math     0          5
#          1          2
#          2          1
# neuro    0         13
#          1          2
# physics  0          8
# stat     0         13
#          1          2
# Name: age, dtype: int64

# %%
df.plot(x='age',y='salary',kind='scatter');

# %%
df.corr(numeric_only=True)
# Out:
#                 salary    gender     years       age  publications
# salary        1.000000 -0.307216  0.307807  0.290491      0.457314
# gender       -0.307216  1.000000 -0.304317 -0.305037     -0.280841
# years         0.307807 -0.304317  1.000000  0.958935      0.339546
# age           0.290491 -0.305037  0.958935  1.000000      0.344125
# publications  0.457314 -0.280841  0.339546  0.344125      1.000000

# %%
import matplotlib.pyplot as plt
df.plot(x='age',y='years',kind='scatter',ylabel="years of Exp",color='red');
plt.ylabel('years of Exp')
plt.title("relation between age & years of Experince");
plt.xlabel('Age');
